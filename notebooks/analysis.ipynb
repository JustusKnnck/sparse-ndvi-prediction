# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    'monthly_samples.csv', 
    parse_dates=['date'], 
    index_col=['date', 'point_id'],
    usecols=['date', 'point_id', 'B1', 'B2', 'B3', 'B4'])
